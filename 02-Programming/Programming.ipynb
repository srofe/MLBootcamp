# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

data = pd.read_csv('lsd_math_score_data.csv')

# %%
print(data)
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score
# 0                      5     1.17                78.93
# 1                     15     2.97                58.20
# 2                     30     3.26                67.47
# 3                     60     4.69                37.47
# 4                    120     5.83                45.65
# 5                    240     6.00                32.92
# 6                    480     6.41                29.97

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
print(data['Avg_Math_Test_Score'])
# Out:
# 0    78.93
# 1    58.20
# 2    67.47
# 3    37.47
# 4    45.65
# 5    32.92
# 6    29.97
# Name: Avg_Math_Test_Score, dtype: float64

# %%
type(data['Avg_Math_Test_Score'])
# Out:
# pandas.core.series.Series

# %%
column_list = ['LSD_ppm', 'Avg_Math_Test_Score']
clean_data = data[column_list]
print(clean_data)
# Out:
#    LSD_ppm  Avg_Math_Test_Score
# 0     1.17                78.93
# 1     2.97                58.20
# 2     3.26                67.47
# 3     4.69                37.47
# 4     5.83                45.65
# 5     6.00                32.92
# 6     6.41                29.97

# %%
type(clean_data)
# Out:
# pandas.core.frame.DataFrame

# %%
time = data[['Time_Delay_in_Minutes']]
LSD = data[['LSD_ppm']]
score = data[['Avg_Math_Test_Score']]

# %%
plt.title('Tissue concentration of LSD over time', fontsize=17)
plt.xlabel('Time in Minutes', fontsize=14)
plt.ylabel('Tissue LSD ppm')
plt.text(x=0, y=-0.3, s='Wagner et al. (a968)')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.style.use('default')
plt.xlim(0, 500)
plt.ylim(1, 7)
plt.plot(time, LSD, color='g')
plt.show()

# %%
regression = LinearRegression()
regression.fit(LSD, score)

# %%
regression.coef_ [0][0]     # The theta1 parameter for the Linear Regression model as a raw value (since coef_ is an array.
regression.intercept_[0]    # The thet0 parameter for the Linear Regression model as a raw value (since intercept_ is an array.
print("Theta0 : ", regression.intercept_[0])
print("Theta1 : ", regression.coef_[0][0])
print("Correlation coefficient (r^2) : ", regression.score(LSD, score))
predicted_score = regression.predict(LSD)
# Out:
# Theta0 :  89.12387376799305
# Theta1 :  -9.009466415296782
# Correlation coefficient (r^2) :  0.8778349707775888

# %%
plt.title('Arithmetic vs LSD-25', fontsize=17)
plt.xlabel('Tissue LSD ppm', fontsize=14)
plt.ylabel('Performance Score', fontsize=14)
plt.xlim(1, 6.5)
plt.ylim((25, 85))
plt.style.use('fivethirtyeight')
plt.scatter(LSD, score, color='blue', s=50, alpha=0.5)
plt.plot(LSD, predicted_score, color='red', linewidth=3)
plt.show()
